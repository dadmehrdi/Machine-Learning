# %% [markdown]
# <span style="color:green; font-size:36px; font-weight:bold;"> Gradient Boost vs. AdaBoost vs. Random Forest</span>
#
# ---

# %% [markdown]
# <span style="color:red; font-size:28px; font-weight:bold;">Classification Trees vs Regression Trees</span>
#
# ---
#
#
# ## Classification Trees
#
# - **Purpose**: Classify instances into distinct categories.
# - **Output**: Discrete labels (e.g., "Yes/No", "Type A/B").
# - **Split Criteria**: Gini impurity, entropy, or classification error.
# - **Decision Process**: Series of questions leading to a class decision.
# - **Use-Cases**: Disease diagnosis, customer segmentation, spam detection.
#
# ## Regression Trees
#
# - **Purpose**: Predict a continuous outcome.
# - **Output**: Continuous values (e.g., price, temperature).
# - **Split Criteria**: Mean squared error (MSE) or mean absolute error (MAE).
# - **Decision Process**: Series of questions leading to a numerical prediction.
# - **Use-Cases**: House price prediction, sales forecasting, age estimation.
#
# ## Key Differences
#
# - **Target Variable**: Discrete for classification trees, continuous for regression trees.
# - **Purity Criteria**: Gini/entropy for classification, variance reduction for regression.
# - **Prediction Method**: Class assignment vs. average value in leaf nodes.
# - **Data Handling**: Segregation of classes vs. reduction of variance.
#
# Both can suffer from overfitting; techniques like pruning and setting maximum depth are used to mitigate this.
#
# ---

# %% [markdown]
# <span style="color:red; font-size:28px; font-weight:bold;">Gini Impurity vs Entropy vs Information Gain</span>
#
#
#
# ## Gini Impurity
# - **Definition**: Measures the frequency at which any element of the dataset will be mislabeled when it is randomly labeled.
# - **Formula**: `1 - Σ (p_i)^2`, where `p_i` is the probability of an item being classified into class i.
# - **Characteristics**: Faster to compute, tends to split the largest class.
#
# ## Entropy
# - **Definition**: Measures the impurity or randomness in the data.
# - **Formula**: `-Σ p_i * log2(p_i)`, where `p_i` is the probability of class i.
# - **Characteristics**: Requires more computation, provides a balanced split.
#
# ## Information Gain
# - **Definition**: Reduction in entropy or impurity after a dataset is split on an attribute.
# - **Formula**: `Entropy(Parent) - Weighted Sum of Entropy(Children)`.
# - **Use**: Used to determine which feature to split on at each step in building a decision tree.
#
# ## Key Points
# - **Gini vs Entropy**: Gini is quicker to compute and is preferred for larger datasets; entropy provides more balanced trees.
# - **Choosing Criterion**: Depends on the nature of the problem and computational efficiency requirements.
# - **Role of Information Gain**: Central in decision tree algorithms, it guides the selection of the splitting attribute.

# %% [markdown]
# <span style="color:red; font-size:28px; font-weight:bold;"> Pruning in Decision Trees</span>
#
#
# - **Purpose**: Reduce tree size to prevent overfitting.
# - **Types**:
#   1. **Pre-Pruning**: Halts tree growth early (e.g., max depth, min samples per leaf).
#   2. **Post-Pruning**: Removes nodes from a fully grown tree (cost complexity pruning).
# - **Benefits**:
#   - Reduces overfitting.
#   - Improves model accuracy on unseen data.
#   - Enhances interpretability.

# %% [markdown]
# <span style="color:red; font-size:28px; font-weight:bold;"> Cross-Validation in Machine Learning</span>
#
# - **Purpose**: Assess a model’s performance on an independent dataset and reduce overfitting.
# - **Method**:
#   1. **Split data**: Divide data into 'k' subsets (folds).
#   2. **Train and Test**: Train on 'k-1' folds, test on the remaining fold.
#   3. **Repeat**: Repeat for each fold and average results.
# - **Types**:
#   1. **k-Fold Cross-Validation**: Data divided into 'k' folds; commonly used.
#   2. **Leave-One-Out (LOO)**: Special case where 'k' equals the number of data points.
# - **Benefits**:
#   - Provides robust estimate of model performance.
#   - Utilizes all available data for training and testing.

# %% [markdown]
# <span style="color:red; font-size:28px; font-weight:bold;"> Bagging (Bootstrap Aggregating)</span>
#
#
# - **Purpose**: Improve the stability and accuracy of machine learning algorithms.
# - **Method**:
#   - Combine multiple models to get an ensemble model.
#   - Each model is trained on a random subset of the data with replacement (bootstrap).
# - **Key Features**:
#   - Reduces variance, helps prevent overfitting.
#   - Models are trained independently.
# - **Common Use**: Often used with decision trees, known as Random Forests.
# - **Benefits**:
#   - Enhances model performance.
#   - Reduces the risk of overfitting compared to individual models.

# %% [markdown]
# <span style="color:red; font-size:28px; font-weight:bold;"> Out-of-Bag (OOB) Error</span>
#
#
# - **Definition**: An estimation of prediction error for bagging models, like Random Forests.
# - **How it Works**:
#   - Each model in a bagging ensemble is trained on a different bootstrap sample from the dataset.
#   - Some instances may not be included in a bootstrap sample and are "out of bag" for that model.
#   - OOB error is calculated using these out-of-bag instances, which act like a validation set.
# - **Advantages**:
#   - Provides an unbiased estimate of model error without needing a separate validation set.
#   - Efficient use of data, as all observations are used for both training and validation.
# - **Usage**:
#   - Commonly used as a performance metric for Random Forest models.

# %% [markdown]
# <span style="color:red; font-size:28px; font-weight:bold;"> Proximity Matrix in Random Forests</span>
#
#
# - **Definition**: A matrix that measures the similarity between pairs of instances based on their paths through the decision trees in a Random Forest.
# - **How it Works**:
#   - When two instances end up in the same leaf node of a tree, their proximity is increased.
#   - Proximity is averaged over all trees in the forest.
# - **Key Features**:
#   - Provides insight into data structure and cluster tendencies.
#   - Higher proximity values indicate more similarity between instances.
# - **Uses**:
#   - Identifying anomalies or outliers.
#   - Data imputation.
#   - Feature selection and dimensionality reduction.
# - **Benefits**:
#   - Enhances understanding of the data.
#   - Can improve model performance by incorporating proximity information.

# %% [markdown]
# <span style="color:red; font-size:28px; font-weight:bold;"> Multidimensional Scaling (MDS) Plot</span>
#
#
# - **Purpose**: To visualize the similarity or dissimilarity of data points in a low-dimensional space.
# - **Key Concept**:
#   - MDS reduces the dimensionality of data while preserving the distances (or dissimilarities) between points as much as possible.
# - **Types**:
#   1. **Metric MDS**: Preserves the pairwise distances between points.
#   2. **Non-metric MDS**: Preserves the order of distances, focusing on the rank order.
# - **Process**:
#   - Starts with a matrix of item-item similarities or dissimilarities.
#   - Seeks a low-dimensional representation that reflects these similarities/dissimilarities.
# - **Applications**:
#   - Visualizing complex datasets with many variables.
#   - Exploring patterns and relationships in data.
# - **Benefits**:
#   - Facilitates intuitive understanding of data structure.
#   - Useful in exploratory data analysis.
#
# MDS plots are particularly helpful in revealing hidden structures in the data, making them valuable for tasks like market research, behavioral science, and bioinformatics.

# %% [markdown]
# <span style="color:red; font-size:28px; font-weight:bold;"> Stumps in Machine Learning</span>
#
#
# - **Definition**: A stump is a decision tree with only one split, essentially the simplest form of a decision tree.
# - **Structure**:
#   - Consists of one root node, which splits into two leaf nodes.
# - **Use in Ensemble Methods**:
#   - Often used as weak learners in boosting algorithms like AdaBoost.
# - **Characteristics**:
#   - Simple and interpretable.
#   - Low predictive power when used alone.
# - **Advantages**:
#   - Quick to train and use.
#   - In ensemble methods, they contribute to a model that is robust to overfitting.
# - **Limitation**:
#   - Limited complexity, can capture only very basic patterns in the data.
#
# Stumps are fundamental in understanding the building blocks of more complex ensemble methods in machine learning.

# %% [markdown]
# <span style="color:red; font-size:28px; font-weight:bold;"> AdaBoost vs Random Forest</span>
#
#
# ## AdaBoost (Adaptive Boosting)
# - **Approach**: Combines multiple weak learners (usually stumps) sequentially.
# - **Weight Adjustment**: Increases weights of misclassified instances, so subsequent learners focus more on them.
# - **Error Reduction**: Focuses on reducing bias and variance by paying more attention to difficult cases.
# - **Model Complexity**: Can become complex as it adds learners to correct errors.
# - **Speed**: Generally slower due to the sequential nature of boosting.
# - **Best For**: Problems where capturing complex patterns is essential, often at the cost of increased risk of overfitting.
#
# ## Random Forest
# - **Approach**: Creates an ensemble of decision trees, each trained on a random subset of data and features.
# - **Decision Making**: Uses majority voting (for classification) or averaging (for regression) across trees.
# - **Error Reduction**: Aims to reduce variance without increasing bias by averaging multiple deep trees.
# - **Model Complexity**: Each tree is complex, but the ensemble reduces overall complexity.
# - **Speed**: Faster and more parallelizable compared to boosting methods.
# - **Best For**: Problems that require a robust model with less risk of overfitting.
#
# ## Key Differences
# - **Learning Method**: AdaBoost builds sequentially, focusing on mistakes; Random Forest builds trees independently.
# - **Handling Overfitting**: AdaBoost can overfit on noisy data, whereas Random Forest is generally more robust.
# - **Interpretability**: Random Forest models are typically easier to interpret than AdaBoost models.
# - **Flexibility**: AdaBoost is sensitive to noisy data and outliers, while Random Forest handles them better.
#
# Both algorithms are powerful, but their effectiveness can vary significantly depending on the nature of the data and the specific problem at hand.

# %% [markdown]
# <span style="color:red; font-size:28px; font-weight:bold;"> AdaBoost vs Gradient Boosting</span>
#
#
# ## AdaBoost (Adaptive Boosting)
# - **Learning Approach**: Sequentially adds weak learners (often stumps), adjusting weights of training instances based on the previous model's errors.
# - **Error Correction**: Increases weights of misclassified instances, forcing subsequent models to focus on them.
# - **Output Update**: Adjusts the final model based on the accuracy of individual weak learners.
# - **Complexity Control**: Primarily through the number of iterations (weak learners).
# - **Sensitivity**: More sensitive to noisy data and outliers.
# - **Best Suited For**: Problems where simpler models need to be combined to improve performance.
#
# ## Gradient Boosting
# - **Learning Approach**: Sequentially adds models, focusing on correcting the residuals (errors) of the previous models.
# - **Error Correction**: Each new model predicts the residual errors of the previous models, refining the overall prediction.
# - **Output Update**: Gradient descent used to minimize loss function, improving the model iteratively.
# - **Complexity Control**: Through learning rate, tree depth, and number of trees.
# - **Sensitivity**: Less sensitive to outliers compared to AdaBoost, but can overfit if not properly tuned.
# - **Best Suited For**: Wide range of problems, especially where capturing complex patterns in data is crucial.
#
# ## Key Differences
# - **Focus of Improvement**: AdaBoost changes instance weights, while Gradient Boosting works on residual errors.
# - **Model Updating Method**: AdaBoost uses accuracy to update, Gradient Boosting uses gradient descent.
# - **Flexibility and Tuning**: Gradient Boosting offers more hyperparameters for fine-tuning (e.g., learning rate, tree depth).
# - **Robustness**: Gradient Boosting generally offers greater robustness to outliers and noisy data.
#
# Both AdaBoost and Gradient Boosting are powerful boosting algorithms, but they differ in their approach to building and improving the ensemble model.

# %% [markdown]
# <h2 style="color: blue; font-weight: bold; font-size: 32px;">Decision Tree Classifier for High-Income Prediction</h2>
#
# The script below uses Decision Tree Classifier to predict high incomes in the IPUMS dataset. It includes data loading, preprocessing (including one-hot encoding of categorical variables like `SEX`, `EDUC`, and `RACE`), training a logistic regression model, evaluating its accuracy, and displaying the model's coefficients for insight into feature influence.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Load your data
main_data_df = pd.read_feather("/Users/dadmehr/R/main_data.feather")

# Filter for the year 2021 and select relevant columns
data = main_data_df[main_data_df['YEAR'] == 2021]

# Convert INCTOT to a binary variable (1 if income is >= 100000, else 0)
data['High_Income'] = (data['INCTOT'] >= 100000).astype(int)
# Out:
# /var/folders/z3/bkgw4vw17fx7qmlcf7_4tdd00000gn/T/ipykernel_29610/3302562650.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['High_Income'] = (data['INCTOT'] >= 100000).astype(int)

# %%
data
# Out:
#           YEAR  SAMPLE     SERIAL      CBSERIAL  NUMPREC  HHWT       CLUSTER  \
# 40172207  2021  202101        1.0  2.021010e+12        1  13.0  2.021000e+12
# 40172208  2021  202101        2.0  2.021010e+12        1  51.0  2.021000e+12
# 40172209  2021  202101        3.0  2.021010e+12        1  17.0  2.021000e+12
# 40172210  2021  202101        4.0  2.021010e+12        1  61.0  2.021000e+12
# 40172211  2021  202101        5.0  2.021010e+12        1  15.0  2.021000e+12
# ...        ...     ...        ...           ...      ...   ...           ...
# 43424801  2021  202101  1440864.0  2.021001e+12        3  49.0  2.021014e+12
# 43424802  2021  202101  1440864.0  2.021001e+12        3  49.0  2.021014e+12
# 43424803  2021  202101  1440864.0  2.021001e+12        3  49.0  2.021014e+12
# 43424804  2021  202101  1440865.0  2.021001e+12        2  88.0  2.021014e+12
# 43424805  2021  202101  1440865.0  2.021001e+12        2  88.0  2.021014e+12
#
# ...

# %%
print(data.columns)
# Out:
# Index(['YEAR', 'SAMPLE', 'SERIAL', 'CBSERIAL', 'NUMPREC', 'HHWT', 'CLUSTER',
#        'STATEICP', 'CITY', 'STRATA', 'GQ', 'HHINCOME', 'COUPLETYPE', 'PERNUM',
#        'PERWT', 'SFTYPE', 'SFRELATE', 'CBSUBFAM', 'CBSFTYPE', 'CBSFRELATE',
#        'MOMLOC', 'MOMRULE', 'POPLOC', 'POPRULE', 'SPLOC', 'SPRULE', 'RELATE',
#        'RELATED', 'SEX', 'AGE', 'MARST', 'MARRNO', 'MARRINYR', 'YRMARR',
#        'FERTYR', 'RACE', 'RACED', 'EDUC', 'EDUCD', 'DEGFIELD', 'DEGFIELDD',
#        'DEGFIELD2', 'DEGFIELD2D', 'EMPSTAT', 'EMPSTATD', 'LABFORCE', 'INCTOT',
#        'TRANWORK', 'TRANTIME', 'DEPARTS', 'ARRIVES', 'mom', 'dad', 'parent',
#        'High_Income'],
#       dtype='object')

# %%
# Selecting relevant features
X = data[['SEX', 'EDUC', 'RACE']]
y = data['High_Income']

# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

feature_names = X_train.columns

classifier = DecisionTreeClassifier(max_depth=3, random_state=42)
classifier.fit(X_train, y_train)

# Predicting and evaluating the model
y_pred = classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {round(accuracy, 3)}")

# Visualizing the tree
plt.figure(figsize=(12, 8), dpi = 600)
plot_tree(classifier, feature_names = X_train.columns, class_names=['Low', 'High'], filled=True)
plt.show()
# Out:
# Accuracy: 0.87

# %% [markdown]
# # Decision Tree Explanation
#
# This decision tree predicts income levels based on the `EDUC` feature. The root node starts with a high Gini impurity, indicating a mixed classification of income levels.
#
# ## Root Node
# - **Split Feature**: `EDUC <= 2.5`
# - **Gini Impurity**: 0.374, suggesting a fair amount of class mixture.
# - **Samples**: 2,276,819, the total number in this node.
# - **Value**: [Low: 1,710,686, High: 566,133], showing more individuals fall below the high-income threshold.
# - **Majority Class**: Low, the tree will predict a low income if no further information is provided.
#
# ## Left Child Node
# - **Split Feature**: `EDUC <= 1.5`
# - **Gini Impurity**: 0.308, slightly purer than the root, indicating a better separation of income levels.
# - **Samples**: 438,081, the subset that meets the left split condition.
# - **Value**: [Low: 83,443, High: 354,638], a larger proportion of high income individuals.
# - **Prediction**: High, suggesting individuals with `EDUC` at or below 1.5 are more likely to have a high income in this model.
#
# ## Right Child Node
# - **Split Feature**: `EDUC <= 9.0`
# - **Gini Impurity**: 0.204, indicating a better separation than the root node.
# - **Samples**: 1,838,738, those that do not meet the left condition.
# - **Value**: [Low: 1,627,243, High: 211,495], showing a majority of low income individuals.
# - **Prediction**: Low, individuals with `EDUC` above 2.5 up to 9 are more likely to have a low income.
#
# The tree's reliance on `EDUC` for all splits suggests its strong predictive power for income levels in this model. It also implies that within this dataset, the level of education is a significant factor in determining income classification.

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, f1_score
import seaborn as sns

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, f1_score

# Calculate the confusion matrix
confusion = confusion_matrix(y_test, y_pred)

# Calculate Sensitivity (True Positive Rate or Recall)
sensitivity = confusion[1, 1] / (confusion[1, 1] + confusion[1, 0])

# Calculate Specificity (True Negative Rate)
specificity = confusion[0, 0] / (confusion[0, 0] + confusion[0, 1])

# Calculate Precision
precision = precision_score(y_test, y_pred)

# Calculate F1-Score
f1 = f1_score(y_test, y_pred)

# Calculate False Positive Rate (FPR)
fpr = confusion[0, 1] / (confusion[0, 0] + confusion[0, 1])

print(f"Sensitivity (True Positive Rate): {sensitivity:.3f}")
print(f"Specificity (True Negative Rate): {specificity:.3f}")
print(f"Precision: {precision:.3f}")
print(f"F1-Score: {f1:.3f}")
print(f"False Positive Rate: {fpr:.3f}")
# Out:
# Sensitivity (True Positive Rate): 0.624
# Specificity (True Negative Rate): 0.951
# Precision: 0.809
# F1-Score: 0.704
# False Positive Rate: 0.049

# %% [markdown]
# ### Sensitivity (True Positive Rate):
#
# - **Definition**: Sensitivity measures the model's ability to correctly identify individuals with high income out of all individuals who actually have high income.
# - **Explanation**: It quantifies the proportion of individuals with high income that the model correctly identifies. A higher sensitivity means that the model is effective at catching most of the individuals with high income and minimizing the chances of missing them (false negatives).
# - **Value**: Sensitivity (True Positive Rate): 0.624
#   - This indicates that the model correctly identifies approximately 62.4% of individuals with high income.
#
# ### Specificity (True Negative Rate):
#
# - **Definition**: Specificity measures the model's ability to correctly identify individuals without high income out of all individuals who actually do not have high income.
# - **Explanation**: It quantifies the proportion of individuals without high income that the model correctly identifies. A higher specificity means that the model is good at correctly identifying individuals without high income and reducing the chances of incorrectly classifying them as having high income (false positives).
# - **Value**: Specificity (True Negative Rate): 0.951
#   - This indicates that the model correctly identifies approximately 95.1% of individuals without high income.
#
# ### Precision:
#
# - **Definition**: Precision measures the proportion of correctly predicted individuals with high income among all individuals predicted to have high income.
# - **Explanation**: It focuses on the quality of the model's predictions for individuals with high income. A higher precision means that a larger proportion of those predicted to have high income actually have it.
# - **Value**: Precision: 0.809
#   - Approximately 80.9% of the individuals predicted to have high income actually have it.
#
# ### F1-Score:
#
# - **Definition**: The F1-Score is the harmonic mean of precision and recall, providing a balance between the two metrics.
# - **Explanation**: It combines both precision and recall into a single metric, which is particularly useful when there is an imbalance between positive and negative classes.
# - **Value**: F1-Score: 0.704
#   - The F1-Score indicates the overall balance between the precision and recall of the model's predictions.
#
# ### False Positive Rate:
#
# - **Definition**: The False Positive Rate measures the proportion of individuals without high income who are incorrectly predicted as having high income.
# - **Explanation**: It quantifies the rate of false alarms, indicating how often individuals without high income are incorrectly classified as having high income.
# - **Value**: False Positive Rate: 0.049
#   - Approximately 4.9% of individuals without high income are incorrectly predicted as having high income.

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Calculate the probability scores for positive class (class 'High')
y_prob = classifier.predict_proba(X_test)[:, 1]

# Calculate the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Calculate the AUC (Area Under the Curve)
roc_auc = roc_auc_score(y_test, y_prob)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.3f})')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # ROC Curve Interpretation
#
# The Receiver Operating Characteristic (ROC) curve and the Area Under the Curve (AUC) are used to evaluate the performance of a binary classification model, in this case, predicting whether an individual's income exceeds $100K.
#
# - **ROC Curve**: The curve plots the True Positive Rate (Sensitivity) against the False Positive Rate (1 - Specificity) at various threshold settings. A model with perfect predictive accuracy would have a curve that goes straight up the y-axis and then along the x-axis.
#
# - **AUC Score**: The AUC score is 0.891, which is very good. It's a measure of the model's ability to distinguish between those who do and do not make over $100K. An AUC score of 1.0 represents a perfect model, while 0.5 represents a model that is no better than random guessing.
#
# - **Interpretation**: The high AUC score suggests that the model is quite effective at predicting high-income earners (those making over \\$100K). The model's ability to discriminate between the two classes (earning more or less than \\$100K) is significantly better than random chance, indicating a strong predictive performance.

# %% [markdown]
# <h2 style="color: blue; font-weight: bold; font-size: 32px;">AdaBoost Classifier</h2>
#
# The script below uses AdaBoost Classifier to predict high incomes in the IPUMS dataset. It includes data loading, preprocessing (including one-hot encoding of categorical variables like `SEX`, `EDUC`, and `RACE`), training a logistic regression model, evaluating its accuracy, and displaying the model's coefficients for insight into feature influence.

# %%
import pandas as pd
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
# Selecting relevant features


# Selecting relevant features
X = data[['SEX', 'EDUC', 'RACE']]
y = data['High_Income']

# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

feature_names = X_train.columns


# Initialize AdaBoost with 3 decision stumps
ada_classifier = AdaBoostClassifier(
    base_estimator=DecisionTreeClassifier(max_depth=1),
    n_estimators=3,
    random_state=42
)

# Fit AdaBoost to the training data
ada_classifier.fit(X_train, y_train)

# Predict and calculate accuracy
y_pred = ada_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f"AdaBoost Model Accuracy: {round(accuracy, 3)}")

# Visualize the decision trees within AdaBoost
for tree_num, tree in enumerate(ada_classifier.estimators_):
    plt.figure(figsize=(4, 3))
    plot_tree(tree, feature_names=X_train.columns, class_names=['Low', 'High'], filled=True)
    plt.title(f'Decision Tree {tree_num + 1} in the AdaBoost Model')
    plt.show()
# Out:
# /Users/dadmehr/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# AdaBoost Model Accuracy: 0.87

# %% [markdown]
# # AdaBoost Decision Trees Interpretation
#
# AdaBoost selects features to split on based on their ability to reduce the model's error. In the given decision trees, `EDUC` is consistently chosen as the splitting feature, implying its strong relationship with the target variable (income level). This suggests that `EDUC` is a dominant predictor and provides the most information gain for classifying individuals into income brackets.
#
# ## Decision Tree 1
# - **Primary Split**: Based on `EDUC`.
# - **Insight**: Lower levels of education (`EDUC <= 2.5`) lead to a higher probability of a six-digit income in this tree, which might be counterintuitive and warrants further investigation.
#
# ## Decision Tree 2
# - **Primary Split**: Also on `EDUC`.
# - **Insight**: Shows a tendency to predict a six-digit income for individuals with an education level above the ninth grade (`EDUC > 9.0`).
#
# ## Decision Tree 3
# - **Primary Split**: Once again on `EDUC`.
# - **Insight**: Suggests that individuals with the lowest education levels (`EDUC <= 1.5`) are more likely to have a six-digit income according to this tree, which could be due to the adaptive boosting focusing on correcting previous misclassifications.
#
# In all trees, the `EDUC` feature is pivotal for predicting income level. If `EDUC` provides a clear distinction between different income levels, AdaBoost will prioritize it for splits to effectively reduce classification error. This reliance on `EDUC` could be indicative of its predictive power in the context of the dataset, overshadowing other features like `SEX`.

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Calculate the confusion matrix
confusion = confusion_matrix(y_test, y_pred)

# Calculate Sensitivity (True Positive Rate or Recall)
sensitivity = confusion[1, 1] / (confusion[1, 1] + confusion[1, 0])

# Calculate Specificity
specificity = confusion[0, 0] / (confusion[0, 0] + confusion[0, 1])

print(f"Sensitivity (True Positive Rate): {sensitivity:.3f}")
print(f"Specificity: {specificity:.3f}")
# Out:
# Sensitivity (True Positive Rate): 0.624
# Specificity: 0.951

# %%
# NOT THIS

# %%
import pandas as pd
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# Create a .01% random subset of the data
subset_size = int(0.0001 * len(data))
subset_data = data.sample(n=subset_size, random_state=42)

# Selecting relevant features
X = subset_data[['SEX', 'EDUC', 'RACE']]
y = subset_data['High_Income']

# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

feature_names = X_train.columns

# Hyperparameter tuning using GridSearchCV
param_grid = {
    'base_estimator__max_depth': [1, 2, 3],  # Tune the depth of the base decision tree
    'n_estimators': [50, 100, 200],          # Tune the number of estimators in AdaBoost
    'learning_rate': [0.1, 0.5, 1.0]       # Tune the learning rate
}

base_estimator = DecisionTreeClassifier(random_state=42)
ada_classifier = AdaBoostClassifier(
    base_estimator=base_estimator,
    random_state=42
)

grid_search = GridSearchCV(ada_classifier, param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_

# Fit AdaBoost with the best hyperparameters to the training data
ada_classifier = AdaBoostClassifier(
    base_estimator=base_estimator,
    n_estimators=best_params['n_estimators'],
    learning_rate=best_params['learning_rate'],
    random_state=42
)
ada_classifier.fit(X_train, y_train)

# Predict and calculate accuracy
y_pred = ada_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f"AdaBoost Model Accuracy: {round(accuracy, 3)}")
print(f"Best Hyperparameters: {best_params}")

# Visualize the decision trees within AdaBoost
#for tree_num, tree in enumerate(ada_classifier.estimators_):
#    plt.figure(figsize=(4, 3))
#    plot_tree(tree, feature_names=feature_names, class_names=['Low', 'High'], filled=True)
#    plt.title(f'Decision Tree {tree_num + 1} in the AdaBoost Model')
#    plt.show()
# Out:
# AdaBoost Model Accuracy: 0.816
# Best Hyperparameters: {'base_estimator__max_depth': 2, 'learning_rate': 0.1, 'n_estimators': 50}

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Calculate the confusion matrix
confusion = confusion_matrix(y_test, y_pred)

# Calculate Sensitivity (True Positive Rate or Recall)
sensitivity = confusion[1, 1] / (confusion[1, 1] + confusion[1, 0])

# Calculate Specificity
specificity = confusion[0, 0] / (confusion[0, 0] + confusion[0, 1])

print(f"Sensitivity (True Positive Rate): {sensitivity:.3f}")
print(f"Specificity: {specificity:.3f}")
# Out:
# Sensitivity (True Positive Rate): 0.607
# Specificity: 0.900

# %% [markdown]
# <h2 style="color: blue; font-weight: bold; font-size: 32px;">Gradient Boosting Classifier</h2>
#
# The script below uses Gradient Boosting Classifier to predict high incomes in the IPUMS dataset. It includes data loading, preprocessing (including one-hot encoding of categorical variables like `SEX`, `EDUC`, and `RACE`), training a logistic regression model, evaluating its accuracy, and displaying the model's coefficients for insight into feature influence.

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Initialize Gradient Boosting Classifier
gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=4, random_state=42)

# Fit Gradient Boosting to the training data
gbc.fit(X_train, y_train)

# Predict and calculate accuracy
y_pred = gbc.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Gradient Boosting Model Accuracy: {round(accuracy, 3)}")

# Visualize the first tree from the gradient boosting model
# The first index [0] accesses the first tree, and the second index [0] accesses the single decision tree within the list.
first_tree = gbc.estimators_[0, 0]
plt.figure(figsize=(20, 10), dpi = 500)
plot_tree(first_tree, feature_names=X_train.columns, class_names=['Low', 'High'], filled=True)
plt.show()
# Out:
# Gradient Boosting Model Accuracy: 0.806

# %% [markdown]
# # Gradient Boosting Model Tree Interpretation
#
# This decision tree is part of a Gradient Boosting model used to predict whether individuals earn a six-digit income, based on `EDUC`, `SEX`, and `RACE`.
#
# - **Root Split**: `EDUC <= 2.5` indicates education level is a significant predictor.
# - **Left Branch**: Further splits by `EDUC` suggest finer distinctions in income levels at lower education levels.
# - **Right Branch**: Splits by `EDUC` again and then by `SEX`, pointing to a combined effect of education and gender on income.
# - **Leaf Nodes**: Represent the model's final predictions with `value` indicating the likelihood of high income.
# - **Model Accuracy**: Achieved an accuracy of 0.8708, indicating a strong predictive performance.
#
# The `friedman_mse` values indicate the error reduction each split brings to the model, guiding the gradient boosting process.

# %% [markdown]
# <h2 style="color: blue; font-weight: bold; font-size: 32px;">Logistic Regression for High-Income Prediction</h2>
#
# The script below uses logistic regression to predict high incomes in the IPUMS dataset. It includes data loading, preprocessing (including one-hot encoding of categorical variables like `SEX`, `EDUC`, and `RACE`), training a logistic regression model, evaluating its accuracy, and displaying the model's coefficients for insight into feature influence.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer


categorical_features = X_train.columns

# We create the OneHotEncoder
encoder = OneHotEncoder()

# Create the ColumnTransformer to apply the encoding only to the categorical variables
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', encoder, categorical_features)
    ],
    remainder='passthrough'  # Leave the rest of the columns untouched
)

# Preprocess the categorical data
X = preprocessor.fit_transform(data[categorical_features])
y = data['High_Income']

# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize Logistic Regression
log_reg = LogisticRegression(random_state=42)

# Fit Logistic Regression to the training data
log_reg.fit(X_train, y_train)

# Predict and calculate accuracy
y_pred = log_reg.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Logistic Regression Model Accuracy with Categorical Variables: {round(accuracy, 3)}")

# Get the one-hot encoded feature names
encoded_features = preprocessor.named_transformers_['cat'].get_feature_names_out(categorical_features)
# Out:
# Logistic Regression Model Accuracy with Categorical Variables: 0.87

# %%
# Get the one-hot encoded feature names
encoded_features = preprocessor.named_transformers_['cat'].get_feature_names_out(categorical_features)

# Define your labels
educ_labels = {
    'EDUC_0': 'N/A or no schooling',
    'EDUC_1': 'Nursery school to grade 4',
    'EDUC_2': 'Grade 5, 6, 7, or 8',
    'EDUC_3': 'Grade 9',
    'EDUC_4': 'Grade 10',
    'EDUC_5': 'Grade 11',
    'EDUC_6': 'Grade 12',
    'EDUC_7': '1 year of college',
    'EDUC_8': '2 years of college',
    'EDUC_9': '3 years of college',
    'EDUC_10': '4 years of college',
    'EDUC_11': '5+ years of college'
}

sex_labels = {
    'SEX_1': 'Male',
    'SEX_2': 'Female'
}

race_labels = {
    'RACE_1': "White", 
    'RACE_2': "Black", 
    'RACE_3': "American Indian",
    'RACE_4': "Chinese", 
    'RACE_5': "Japanese", 
    'RACE_6': "Other Asian",
    'RACE_7': "Other race", 
    'RACE_8': "Two races", 
    'RACE_9': "Three or more races"
}

# Combine all labels into a single dictionary
all_labels = {**educ_labels, **sex_labels, **race_labels}

# Map the encoded features to the labels
labeled_features = [all_labels[feature] if feature in all_labels else feature for feature in encoded_features]

# Print the coefficients of the model using the new labels
coefficients = pd.DataFrame(log_reg.coef_[0], index=labeled_features, columns=['Coefficient'])
print(coefficients)
# Out:
#                            Coefficient
# Male                         -0.110673
# Female                       -0.872013
# N/A or no schooling           2.761422
# Nursery school to grade 4     4.618894
# Grade 5, 6, 7, or 8           2.416402
# Grade 9                      -0.672630
# Grade 10                     -2.992694
# Grade 11                     -3.343563
# Grade 12                     -1.943663
# 1 year of college            -1.363270
# 2 years of college           -1.116737
# 4 years of college           -0.028571
# 5+ years of college           0.681724
# White                         0.185766
# Black                        -0.302841
# American Indian              -0.495519
# Chinese                       0.101845
# Japanese                      0.268510
# Other Asian                   0.123060
# Other race                   -0.996145
# Two races                    -0.141825
# Three or more races           0.274462

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate and print accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Logistic Regression Model Accuracy: {round(accuracy, 3)}")

# Print classification report for other metrics
print(classification_report(y_test, y_pred))
# Out:
# Logistic Regression Model Accuracy: 0.87
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92    733278
#            1       0.82      0.61      0.70    242502
#
#     accuracy                           0.87    975780
#    macro avg       0.85      0.78      0.81    975780
# weighted avg       0.87      0.87      0.86    975780

# %% [markdown]
# ## Accuracy and Other Metrics
# - **Overall Accuracy of 0.87** shows that the model is correct in its predictions 87% of the time.
# - **Precision for Class 1 (0.82)** implies that when the model predicts an income above $100K, it is correct 82% of the time.
#
# - **Recall for Class 1 (0.61)** indicates that the model identifies 61% of all actual cases of income above $100K.
# - **F1-Score for Class 1 (0.70)** is the harmonic mean of precision and recall, indicating a balance between the precision and the recall.

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Calculate the confusion matrix
confusion = confusion_matrix(y_test, y_pred)

# Calculate Sensitivity (True Positive Rate or Recall)
sensitivity = confusion[1, 1] / (confusion[1, 1] + confusion[1, 0])

# Calculate Specificity
specificity = confusion[0, 0] / (confusion[0, 0] + confusion[0, 1])

print(f"Sensitivity (True Positive Rate): {sensitivity:.3f}")
print(f"Specificity: {specificity:.3f}")
# Out:
# Sensitivity (True Positive Rate): 0.610
# Specificity: 0.956

# %% [markdown]
# ## Confusion Matrix
# - **True Negatives (TN): 700,769** - The model correctly predicted a large number of individuals as having income below $100K.
#
# - **False Positives (FP): 32,509** - These are cases where the model incorrectly predicted individuals to have income above $100K, but actually, they do not.
#
# - **False Negatives (FN): 94,515** - Here, the model failed to identify a significant number of individuals who actually have income above $100K.
#
# - **True Positives (TP): 147,987** - The model correctly identified these individuals as having income above $100K.
#
# The high TN value indicates good model specificity, while the TP value indicates sensitivity. However, the presence of a considerable number of FN suggests that the model might be conservative in predicting the higher-income class.

# %%
# ROC Curve and AUC
y_pred_proba = log_reg.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.figure(figsize=(5, 4))
plt.plot(fpr, tpr, label=f'AUC = {roc_auc_score(y_test, y_pred_proba):.2f}')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %% [markdown]
# ## ROC Curve and AUC
# - **AUC of 0.90** reflects the model's excellent ability to differentiate between the two classes. A value of 1.0 represents a perfect model, and 0.90 is quite close to that, indicating high predictive power.

# %%
# Get the one-hot encoded feature names
encoded_features = preprocessor.named_transformers_['cat'].get_feature_names_out(categorical_features)

# Mapping one-hot encoded feature names to labels
feature_label_mapping = {**educ_labels, **sex_labels, **race_labels}
labeled_coefficients_index = [feature_label_mapping.get(feature, feature) for feature in encoded_features]

# Create a DataFrame for coefficients with labeled index
labeled_coefficients = pd.DataFrame(log_reg.coef_[0], index=labeled_coefficients_index, columns=['Coefficient'])

# Coefficients Visualization with labels
plt.figure(figsize=(10, 8))
labeled_coefficients.sort_values(by='Coefficient').plot(kind='bar')
plt.title('Feature Coefficients with Labels')
plt.show()

# %% [markdown]
# # Logistic Regression Model Coefficients Interpretation
#
# - **Positive Coefficients:** Features like `5+ years of college` have positive coefficients, indicating a higher likelihood of income above $100K.
#
# - **Negative Coefficients:** Features such as `Grade 10` have negative coefficients, suggesting a lower likelihood of income above $100K.
#
# - **Education Level:** The model assigns varying weights to different education levels, not always in an expected manner, which may require further investigation.

# %%
educ_labels = {
    0: 'N/A or no schooling',
    1: 'Nursery school to grade 4',
    2: 'Grade 5, 6, 7, or 8',
    3: 'Grade 9',
    4: 'Grade 10',
    5: 'Grade 11',
    6: 'Grade 12',
    7: '1 year of college',
    8: '2 years of college',
    9: '3 years of college',
    10: '4 years of college',
    11: '5+ years of college'
}

sex_labels = {
    1: 'Male',
    2: 'Female'
}

race_labels = {
    1: "White", 
    2: "Black", 
    3: "American Indian",
    4: "Chinese", 
    5: "Japanese", 
    6: "Other Asian",
    7: "Other race", 
    8: "Two races", 
    9: "Three or more races"
}

# %% [markdown]
# # RBF vs Linear Kernel in SVC
#
# Support Vector Machines (SVMs) are a set of supervised learning methods used for classification, regression, and outliers detection. The main difference between using a Radial Basis Function (RBF) kernel and a linear kernel in an SVM lies in their ability to handle the data's linearity.
#
# ## Linear Kernel
# - The **linear kernel** is used when the data is linearly separable, meaning it can be separated into classes using a single straight line (or its higher-dimensional equivalent).
# - It is computationally less intensive and often requires less model tuning.
# - The linear kernel performs well when there are a lot of features, and especially when the number of features is greater than the number of samples.
#
# ## RBF Kernel
# - The **RBF kernel**, also known as the Gaussian kernel, can handle cases where the relationship between class labels and attributes is non-linear.
# - It maps input features into higher-dimensional space where a linear separation is possible, using a process known as the "kernel trick."
# - The RBF kernel has parameters like `gamma` that control the complexity of the model. A higher gamma value leads to more complex models, which can capture intricate patterns but also risk overfitting.
# - It is more suitable for datasets where the boundary between classes is not linear and cannot be described using straight lines.
#
# ## Choosing Between RBF and Linear
# - The choice between an RBF and a linear kernel depends on the dataset at hand. If the data is not linearly separable, the RBF kernel might perform better at the cost of increased computational complexity.
# - It is often recommended to try both types of kernels and perform cross-validation to see which yields better performance metrics for a particular dataset.

# %% [markdown]
# <h2 style="color: blue; font-weight: bold; font-size: 32px;">Support Vector Machines (SVMs)</h2>

# %%
import time
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

data = main_data_df[main_data_df['YEAR'] == 2021]
data['High_Income'] = (data['INCTOT'] >= 100000).astype(int)


# Create a 1% random subset of the data
subset_size = int(0.01 * len(data))
subset_data = data.sample(n=subset_size, random_state=42)

# Selecting relevant features
X = subset_data[['SEX', 'EDUC', 'RACE']]
y = subset_data['High_Income']

# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize Support Vector Classifier
svc_classifier = SVC(kernel='linear', probability=False, random_state=42)

# Measure execution time
start_time = time.time()

# Fit SVC to the training data
svc_classifier.fit(X_train, y_train)

# Predict and calculate accuracy
y_pred = svc_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

end_time = time.time()
execution_time = end_time - start_time

print(f"SVC Model Accuracy: {round(accuracy, 3)}")
print(f"Execution Time: {round(execution_time, 2)} seconds")
# Out:
# SVC Model Accuracy: 0.863
# Execution Time: 8.4 seconds

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, f1_score
import seaborn as sns

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# <h2 style="color: blue; font-weight: bold; font-size: 32px;">Radial Basis Function (RBF)</h2>

# %%
from sklearn.svm import SVC

# Initialize Support Vector Classifier with RBF kernel
svc_classifier = SVC(kernel='rbf', probability=False, random_state=42)

# Measure execution time
start_time = time.time()

# Fit SVC to the training data
svc_classifier.fit(X_train, y_train)

# Predict and calculate accuracy
y_pred = svc_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

end_time = time.time()
execution_time = end_time - start_time

print(f"SVC Model Accuracy: {round(accuracy, 3)}")
print(f"Execution Time: {round(execution_time, 2)} seconds")
# Out:
# SVC Model Accuracy: 0.873
# Execution Time: 4.67 seconds

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, f1_score
import seaborn as sns

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# <h2 style="color: blue; font-weight: bold; font-size: 32px;">Neural Network</h2>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
import pandas as pd

# Scaling features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Convert labels to categorical
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# Neural network architecture
model = Sequential([
    Dense(64, input_dim=X_train_scaled.shape[1], activation='relu'),
    Dense(32, activation='relu'),
    Dense(2, activation='softmax')  # 2 for binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train_scaled, y_train_categorical, epochs=50, batch_size=512, verbose=0)

# Evaluate the model
y_pred_categorical = model.predict(X_test_scaled)
y_pred = [1 if prob[1] > 0.5 else 0 for prob in y_pred_categorical]

loss, accuracy = model.evaluate(X_test_scaled, y_test_categorical)
print(f'Neural Network Model Accuracy: {accuracy:.3f}')
# Out:
# ...
# 305/305 [==============================] - 0s 324us/step - loss: 0.3226 - accuracy: 0.8714
# Neural Network Model Accuracy: 0.871

# %%
# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
